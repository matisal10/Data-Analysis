# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import matplotlib.patheffects as pa

# %%
excel = pd.read_csv('finanzas.csv')

# %%
excel
# Out:
#         Fecha  Elon Mosk  Bill Gate
# 0    2/1/2018     171.42     176.85
# 1    3/1/2018     164.67     171.29
# 2    4/1/2018     184.33     184.33
# 3    5/1/2018     176.85     176.85
# 4    8/1/2018     178.28     167.60
# ..        ...        ...        ...
# 358       NaN        NaN        NaN
# 359       NaN        NaN        NaN
# 360       NaN        NaN        NaN
# 361       NaN        NaN        NaN
# 362       NaN        NaN        NaN
#
# [363 rows x 3 columns]

# %%
vol = excel[excel.Categoría == 'Hogar']
vol.head()
# Out:
#        Fecha          Vendedor Región    Artículo Categoría  Unidades  \
# 13  2/1/2016      Steve Ashton   Este  Detergente     Hogar         7
# 19  2/1/2016  Trevor Snodgrass    Sur      Escoba     Hogar        11
# 27  2/1/2016        Sarah Bond   Este      Escoba     Hogar        12
# 30  3/1/2016        Dustin Gee  Oeste       Lejía     Hogar        11
# 31  3/1/2016        Dustin Gee   Este      Escoba     Hogar        14
#
#     Ganancia
# 13        17
# 19        40
# 27        44
# 30        34
# 31        51

# %%
vol.Artículo.value_counts()
# Out:
# Escoba           31
# Escobillón       25
# Detergente       24
# Lejía            24
# Limpiavidrios    18
# Bombilla         18
# Trapo Piso       13
# Name: Artículo, dtype: int64

# %%
vol.Artículo.value_counts().plot()
# Out:
# <AxesSubplot:>
